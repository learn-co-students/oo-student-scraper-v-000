# %%
require 'open-uri'
require 'pry'
require 'nokogiri'
class Scraper
	html = File.read('fixtures/student-site/_site/index.html')
	

  def self.scrape_index_page(index_url = 'fixtures/student-site/_site/index.html')
  	students = {}
  	html = File.read(index_url)
  	doc = Nokogiri::HTML(html)
    name = doc.css(".card-text-container h4")
    location = doc.css(".card-text-container p")
    profile_url = doc.css(".student-card a").attribute("href").value

  end

  def self.scrape_profile_page(profile_url)
    
  end

end

# %%
Scraper.scrape_index_page

# %%
Scraper.scrape_index_page

# %%
Scraper.scrape_index_page

# %%
Scraper.scrape_index_page

# %%
Scraper.scrape_index_page

# %%
Scraper.scrape_index_page
# Out:
# NameError: uninitialized constant Scraper
# (pry):1:in `<main>'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:355:in `eval'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:355:in `evaluate_ruby'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:323:in `handle_line'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:243:in `block (2 levels) in eval'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:242:in `catch'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:242:in `block in eval'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:241:in `catch'
# /Users/nothingisfunny/.rvm/gems/ruby-2.2.3/gems/pry-0.10.3/lib/pry/pry_instance.rb:241:in `eval'
# ...

# %%
require 'open-uri'
require 'pry'
require 'nokogiri'
class Scraper
	html = File.read('fixtures/student-site/_site/index.html')
	

  def self.scrape_index_page(index_url = 'fixtures/student-site/_site/index.html')
  	students = {}
  	html = File.read(index_url)
  	doc = Nokogiri::HTML(html)
    name = doc.css(".card-text-container h4")
    location = doc.css(".card-text-container p")
    profile_url = doc.css(".student-card a")

  end

  def self.scrape_profile_page(profile_url)
    
  end

end
# Out:
# :scrape_profile_page

# %%
Scraper.scrape_index_page
# Out:
# [#<Nokogiri::XML::Element:0x3ff09daa8f70 name="a" attributes=[#<Nokogiri::XML::Attr:0x3ff09e261780 name="href" value="students/ryan-johnson.html">] children=[#<Nokogiri::XML::Text:0x3ff09e261118 "\n              ">, #<Nokogiri::XML::Element:0x3ff09e261014 name="div" attributes=[#<Nokogiri::XML::Attr:0x3ff09e260f88 name="class" value="view-profile-div">] children=[#<Nokogiri::XML::Text:0x3ff09e260808 "\n                ">, #<Nokogiri::XML::Element:0x3ff09e2606f0 name="h3" attributes=[#<Nokogiri::XML::Attr:0x3ff09e26054c name="class" value="view-profile-text">] children=[#<Nokogiri::XML::Text:0x3ff09e26068c "View Profile">]>, #<Nokogiri::XML::Text:0x3ff09dccbf3c "\n              ">]>, #<Nokogiri::XML::Text:0x3ff09dccbd20 "\n              ">, #<Nokogiri::XML::Element:0x3ff09dccbc30 name="div" attributes=[#<Nokogiri::XML::Attr:0x3ff09dccbba4 name="class" value="card-text-container">] children=[#<Nokogiri::XML::Text:0x3ff09dccb6a4 "\n                ">, #<Nokogiri::XML::Element:0x3ff09dcc
# ...
